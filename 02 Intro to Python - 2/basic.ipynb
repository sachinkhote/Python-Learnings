# %%
print("hello world")
# Out:
# hello world

# %%
print("mango","banana","grapes")
print("mango","banana","grapes",sep=",")
# Out:
# mango banana grapes
# mango,banana,grapes

# %%
print("thesee are my fruits", end=": \n")
# Out:
# thesee are my fruits:

# %%
print("these are my fruits", end=" : ")
print("mango","banana","grapes",sep=", " , end=". \n")
print("I love to eat fruits")
# Out:
# these are my fruits : mango, banana, grapes.
# I love to eat fruits

# %%
a= input("Enter a number: ")

# %%
print(a)
# Out:
# 5

# %%
input()
# Out:
# 'hi guys welcome to my vlog'

# %%
# This is a sample Python comment

# %%
#indentation
x=5
if x>3:
    print("x is greater than 3")
# Out:
# x is greater than 3

# %%
x=10

# %%
print(x)        # This will print the value of x(updated value)
# Out:
# 10

# %%
'''multi line comment
this is a multi line comment    
used to explain code in detail
'''
# Out:
# 'multi line comment\nthis is a multi line comment    \nused to explain code in detail\n'

# %%
# assigning one value to multiple variables in single line
a = b = c = 5
print(a, b, c)
# Out:
# 5 5 5

# %%
# assigning multiple values to multiple variables in single line
a,b,c = 1,2,3
print(a,b,c)
# Out:
# 1 2 3
